# %%
#import libraries 
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import numpy as np 
import os 
import matplotlib.pyplot as plt
import seaborn as sns
import scipy

# %%
#Import Path
path = r'C:\Users\kanch\Documents\World Happiness Report\02 Data'

# %%
path
# Out:
# 'C:\\Users\\kanch\\Documents\\World Happiness Report\\02 Data'

# %% [markdown]
# # df_2015.csv,df_2016,df_2017,df_2018,df_2019 importing csv files

# %%
#open 2015.csv 
df_2015 = pd.read_csv(os.path.join(path, '2015.csv'),index_col = False)

# %%
#open 2016.csv
df_2016 = pd.read_csv(os.path.join(path, '2016.csv'),index_col = False)

# %%
#open 2017.csv
df_2017 = pd.read_csv(os.path.join(path, '2017.csv'),index_col = False)

# %%
#open 2018.csv
df_2018 = pd.read_csv(os.path.join(path, '2018.csv'),index_col = False)

# %%
#open 2019.csv
df_2019 = pd.read_csv(os.path.join(path, '2019.csv'),index_col = False)

# %% [markdown]
# # 01 df_2015

# %%
df_2015
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %%
#total amount of rows and columns
df_2015.shape
# Out:
# (158, 12)

# %%
#list column names
df_2015.columns.to_list()
# Out:
# ['Country',
#  'Region',
#  'Happiness Rank',
#  'Happiness Score',
#  'Standard Error',
#  'Economy (GDP per Capita)',
#  'Family',
#  'Health (Life Expectancy)',
#  'Freedom',
#  'Trust (Government Corruption)',
#  'Generosity',
#  'Dystopia Residual']

# %%
#check if there is mixed data types 
for col in df_2015.columns.tolist():
  weird = (df_2015[[col]].applymap(type) != df_2015[[col]].iloc[0].apply(type)).any(axis = 1)
  if len (df_2015[weird]) > 0:
    print (col)

# %%
#describe the datatypes
df_2015.dtypes
# Out:
# Country                           object
# Region                            object
# Happiness Rank                     int64
# Happiness Score                  float64
# Standard Error                   float64
# Economy (GDP per Capita)         float64
# Family                           float64
# Health (Life Expectancy)         float64
# Freedom                          float64
# Trust (Government Corruption)    float64
# Generosity                       float64
# Dystopia Residual                float64
# dtype: object

# %%
#new_columns = df_2015.columns.str.replace(' ', '_')
#df_2015.columns = new_columns
df_2015
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %% [markdown]
# #Finding missing value

# %%
df_2015.isnull().sum()
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %% [markdown]
# # There is no missing value

# %%
# Check for duplicates
df_2015_dups = df_2015[df_2015.duplicated()]

# %%
df_2015_dups
# Out:
# Empty DataFrame
# Columns: [Country, Region, Happiness Rank, Happiness Score, Standard Error, Economy (GDP per Capita), Family, Health (Life Expectancy), Freedom, Trust (Government Corruption), Generosity, Dystopia Residual]
# Index: []

# %% [markdown]
# # There are no duplicates

# %% [markdown]
# # 02 df_2016

# %%
df_2016
# Out:
#          Country                           Region  Happiness Rank  \
# 0        Denmark                   Western Europe               1
# 1    Switzerland                   Western Europe               2
# 2        Iceland                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4        Finland                   Western Europe               5
# ..           ...                              ...             ...
# 152        Benin               Sub-Saharan Africa             153
# 153  Afghanistan                    Southern Asia             154
# 154         Togo               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
#
#      Happiness Score  Lower Confidence Interval  Upper Confidence Interval  \
# 0              7.526                      7.460                      7.592
# ...

# %%
#total amount of rows and columns
df_2016.shape
# Out:
# (157, 13)

# %%
#list column names
df_2016.columns.to_list()
# Out:
# ['Country',
#  'Region',
#  'Happiness Rank',
#  'Happiness Score',
#  'Lower Confidence Interval',
#  'Upper Confidence Interval',
#  'Economy (GDP per Capita)',
#  'Family',
#  'Health (Life Expectancy)',
#  'Freedom',
#  'Trust (Government Corruption)',
#  'Generosity',
#  'Dystopia Residual']

# %%
#check if there is mixed data types 
for col in df_2016.columns.tolist():
  weird = (df_2016[[col]].applymap(type) != df_2016[[col]].iloc[0].apply(type)).any(axis = 1)
  if len (df_2016[weird]) > 0:
    print (col)

# %%
#describe the datatypes
df_2016.dtypes
# Out:
# Country                           object
# Region                            object
# Happiness Rank                     int64
# Happiness Score                  float64
# Lower Confidence Interval        float64
# Upper Confidence Interval        float64
# Economy (GDP per Capita)         float64
# Family                           float64
# Health (Life Expectancy)         float64
# Freedom                          float64
# Trust (Government Corruption)    float64
# Generosity                       float64
# Dystopia Residual                float64
# dtype: object

# %%
#new_columns = df_2016.columns.str.replace(' ', '_')
#df_2016.columns = new_columns
df_2016
# Out:
#          Country                           Region  Happiness Rank  \
# 0        Denmark                   Western Europe               1
# 1    Switzerland                   Western Europe               2
# 2        Iceland                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4        Finland                   Western Europe               5
# ..           ...                              ...             ...
# 152        Benin               Sub-Saharan Africa             153
# 153  Afghanistan                    Southern Asia             154
# 154         Togo               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
#
#      Happiness Score  Lower Confidence Interval  Upper Confidence Interval  \
# 0              7.526                      7.460                      7.592
# ...

# %% [markdown]
# #Finding missing values

# %%
df_2016.isnull().sum()
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Lower Confidence Interval        0
# Upper Confidence Interval        0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %% [markdown]
# #There are no missing values

# %%
# Check for duplicates
df_2016_dups = df_2016[df_2016.duplicated()]

# %%
df_2016_dups
# Out:
# Empty DataFrame
# Columns: [Country, Region, Happiness Rank, Happiness Score, Lower Confidence Interval, Upper Confidence Interval, Economy (GDP per Capita), Family, Health (Life Expectancy), Freedom, Trust (Government Corruption), Generosity, Dystopia Residual]
# Index: []

# %% [markdown]
# #There are no duplicates

# %% [markdown]
# # 03 df_2017

# %%
df_2017
# Out:
#                       Country  Happiness.Rank  Happiness.Score  Whisker.high  \
# 0                      Norway               1            7.537      7.594445
# 1                     Denmark               2            7.522      7.581728
# 2                     Iceland               3            7.504      7.622030
# 3                 Switzerland               4            7.494      7.561772
# 4                     Finland               5            7.469      7.527542
# ..                        ...             ...              ...           ...
# 150                    Rwanda             151            3.471      3.543030
# 151                     Syria             152            3.462      3.663669
# 152                  Tanzania             153            3.349      3.461430
# 153                   Burundi             154            2.905      3.074690
# 154  Central African Republic             155            2.693      2.864884
#
# ...

# %%
#total amount of rows and columns
df_2017.shape
# Out:
# (155, 12)

# %%
#list column names
df_2017.columns.to_list()
# Out:
# ['Country',
#  'Happiness.Rank',
#  'Happiness.Score',
#  'Whisker.high',
#  'Whisker.low',
#  'Economy..GDP.per.Capita.',
#  'Family',
#  'Health..Life.Expectancy.',
#  'Freedom',
#  'Generosity',
#  'Trust..Government.Corruption.',
#  'Dystopia.Residual']

# %%
#check if there is mixed data types 
for col in df_2017.columns.tolist():
  weird = (df_2017[[col]].applymap(type) != df_2017[[col]].iloc[0].apply(type)).any(axis = 1)
  if len (df_2017[weird]) > 0:
    print (col)

# %%
#describe the datatypes
df_2017.dtypes
# Out:
# Country                           object
# Happiness.Rank                     int64
# Happiness.Score                  float64
# Whisker.high                     float64
# Whisker.low                      float64
# Economy..GDP.per.Capita.         float64
# Family                           float64
# Health..Life.Expectancy.         float64
# Freedom                          float64
# Generosity                       float64
# Trust..Government.Corruption.    float64
# Dystopia.Residual                float64
# dtype: object

# %%
#new_columns = df_2017.columns.str.replace(' ', '_')
#new_columns = df_2017.columns.str.replace('..',' ')
#new_columns_2 = new_columns.str.replace('\.\.',' ')
#df_2017.columns = new_columns_2
df_2017
# Out:
#                       Country  Happiness.Rank  Happiness.Score  Whisker.high  \
# 0                      Norway               1            7.537      7.594445
# 1                     Denmark               2            7.522      7.581728
# 2                     Iceland               3            7.504      7.622030
# 3                 Switzerland               4            7.494      7.561772
# 4                     Finland               5            7.469      7.527542
# ..                        ...             ...              ...           ...
# 150                    Rwanda             151            3.471      3.543030
# 151                     Syria             152            3.462      3.663669
# 152                  Tanzania             153            3.349      3.461430
# 153                   Burundi             154            2.905      3.074690
# 154  Central African Republic             155            2.693      2.864884
#
# ...

# %% [markdown]
# #Finding missing values

# %%
df_2017.isnull().sum()
# Out:
# Country                          0
# Happiness.Rank                   0
# Happiness.Score                  0
# Whisker.high                     0
# Whisker.low                      0
# Economy..GDP.per.Capita.         0
# Family                           0
# Health..Life.Expectancy.         0
# Freedom                          0
# Generosity                       0
# Trust..Government.Corruption.    0
# Dystopia.Residual                0
# dtype: int64

# %% [markdown]
# #There are no missing values

# %%
# Check for duplicates
df_2017_dups = df_2017[df_2017.duplicated()]

# %%
df_2017_dups
# Out:
# Empty DataFrame
# Columns: [Country, Happiness.Rank, Happiness.Score, Whisker.high, Whisker.low, Economy..GDP.per.Capita., Family, Health..Life.Expectancy., Freedom, Generosity, Trust..Government.Corruption., Dystopia.Residual]
# Index: []

# %% [markdown]
# #There are no duplicate values

# %% [markdown]
# # 04 df_2018

# %%
df_2018
# Out:
#      Overall rank         Country or region  Score  GDP per capita  \
# 0               1                   Finland  7.632           1.305
# 1               2                    Norway  7.594           1.456
# 2               3                   Denmark  7.555           1.351
# 3               4                   Iceland  7.495           1.343
# 4               5               Switzerland  7.487           1.420
# ..            ...                       ...    ...             ...
# 151           152                     Yemen  3.355           0.442
# 152           153                  Tanzania  3.303           0.455
# 153           154               South Sudan  3.254           0.337
# 154           155  Central African Republic  3.083           0.024
# 155           156                   Burundi  2.905           0.091
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 0             1.592                    0.874                         0.681
# ...

# %%
#total amount of rows and columns
df_2018.shape
# Out:
# (156, 9)

# %%
#list column names
df_2018.columns.to_list()
# Out:
# ['Overall rank',
#  'Country or region',
#  'Score',
#  'GDP per capita',
#  'Social support',
#  'Healthy life expectancy',
#  'Freedom to make life choices',
#  'Generosity',
#  'Perceptions of corruption']

# %%
#check if there is mixed data types 
for col in df_2018.columns.tolist():
  weird = (df_2018[[col]].applymap(type) != df_2018[[col]].iloc[0].apply(type)).any(axis = 1)
  if len (df_2018[weird]) > 0:
    print (col)

# %%
#describe the datatypes
df_2018.dtypes
# Out:
# Overall rank                      int64
# Country or region                object
# Score                           float64
# GDP per capita                  float64
# Social support                  float64
# Healthy life expectancy         float64
# Freedom to make life choices    float64
# Generosity                      float64
# Perceptions of corruption       float64
# dtype: object

# %%
#new_columns = df_2018.columns.str.replace(' ', '_')
#df_2018.columns = new_columns
df_2018
# Out:
#      Overall rank         Country or region  Score  GDP per capita  \
# 0               1                   Finland  7.632           1.305
# 1               2                    Norway  7.594           1.456
# 2               3                   Denmark  7.555           1.351
# 3               4                   Iceland  7.495           1.343
# 4               5               Switzerland  7.487           1.420
# ..            ...                       ...    ...             ...
# 151           152                     Yemen  3.355           0.442
# 152           153                  Tanzania  3.303           0.455
# 153           154               South Sudan  3.254           0.337
# 154           155  Central African Republic  3.083           0.024
# 155           156                   Burundi  2.905           0.091
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 0             1.592                    0.874                         0.681
# ...

# %% [markdown]
# #Finding missing values

# %%
df_2018.isnull().sum()
# Out:
# Overall rank                    0
# Country or region               0
# Score                           0
# GDP per capita                  0
# Social support                  0
# Healthy life expectancy         0
# Freedom to make life choices    0
# Generosity                      0
# Perceptions of corruption       1
# dtype: int64

# %% [markdown]
# #There is 1 missing value in the "Perceptions_of_corruption" column.

# %%
# Check for duplicates
df_2018_dups = df_2018[df_2018.duplicated()]

# %%
df_2018_dups
# Out:
# Empty DataFrame
# Columns: [Overall rank, Country or region, Score, GDP per capita, Social support, Healthy life expectancy, Freedom to make life choices, Generosity, Perceptions of corruption]
# Index: []

# %% [markdown]
# #There are no duplicates

# %% [markdown]
# # df_2019

# %%
df_2019
# Out:
#      Overall rank         Country or region  Score  GDP per capita  \
# 0               1                   Finland  7.769           1.340
# 1               2                   Denmark  7.600           1.383
# 2               3                    Norway  7.554           1.488
# 3               4                   Iceland  7.494           1.380
# 4               5               Netherlands  7.488           1.396
# ..            ...                       ...    ...             ...
# 151           152                    Rwanda  3.334           0.359
# 152           153                  Tanzania  3.231           0.476
# 153           154               Afghanistan  3.203           0.350
# 154           155  Central African Republic  3.083           0.026
# 155           156               South Sudan  2.853           0.306
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 0             1.587                    0.986                         0.596
# ...

# %%
#total amount of rows and columns
df_2019.shape
# Out:
# (156, 9)

# %%
#list column names
df_2019.columns.to_list()
# Out:
# ['Overall rank',
#  'Country or region',
#  'Score',
#  'GDP per capita',
#  'Social support',
#  'Healthy life expectancy',
#  'Freedom to make life choices',
#  'Generosity',
#  'Perceptions of corruption']

# %%
#check if there is mixed data types 
for col in df_2019.columns.tolist():
  weird = (df_2019[[col]].applymap(type) != df_2019[[col]].iloc[0].apply(type)).any(axis = 1)
  if len (df_2019[weird]) > 0:
    print (col)

# %%
#describe the datatypes
df_2019.dtypes
# Out:
# Overall rank                      int64
# Country or region                object
# Score                           float64
# GDP per capita                  float64
# Social support                  float64
# Healthy life expectancy         float64
# Freedom to make life choices    float64
# Generosity                      float64
# Perceptions of corruption       float64
# dtype: object

# %%
#new_columns = df_2019.columns.str.replace(' ', '_')
#df_2019.columns = new_columns
df_2019
# Out:
#      Overall rank         Country or region  Score  GDP per capita  \
# 0               1                   Finland  7.769           1.340
# 1               2                   Denmark  7.600           1.383
# 2               3                    Norway  7.554           1.488
# 3               4                   Iceland  7.494           1.380
# 4               5               Netherlands  7.488           1.396
# ..            ...                       ...    ...             ...
# 151           152                    Rwanda  3.334           0.359
# 152           153                  Tanzania  3.231           0.476
# 153           154               Afghanistan  3.203           0.350
# 154           155  Central African Republic  3.083           0.026
# 155           156               South Sudan  2.853           0.306
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 0             1.587                    0.986                         0.596
# ...

# %% [markdown]
# #Finding missing values

# %%
df_2019.isnull().sum()
# Out:
# Overall rank                    0
# Country or region               0
# Score                           0
# GDP per capita                  0
# Social support                  0
# Healthy life expectancy         0
# Freedom to make life choices    0
# Generosity                      0
# Perceptions of corruption       0
# dtype: int64

# %% [markdown]
# #There are no misssing values

# %%
# Check for duplicates
df_2019_dups = df_2019[df_2018.duplicated()]

# %%
df_2019_dups
# Out:
# Empty DataFrame
# Columns: [Overall rank, Country or region, Score, GDP per capita, Social support, Healthy life expectancy, Freedom to make life choices, Generosity, Perceptions of corruption]
# Index: []

# %% [markdown]
# #There are no Duplicates

# %% [markdown]
# # Data Exploration

# %%
# show first few records for each dataset
for i, df in enumerate(dfs):
    print (f'201{i+5} dataset:')
    display (dfs[i].head(3))
# Out:
# 2015 dataset:
#        Country          Region  Happiness_Rank  Happiness_Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
#
#    Standard_Error  Economy_(GDP_per_Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
#
#    Health_(Life_Expectancy)  Freedom  Trust_(Government_Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# 2                   0.87464  0.64938                        0.48357
#
#    Generosity  Dystopia_Residual  Year
# 0     0.29678            2.51738  2015
# 1     0.43630            2.70201  2015
# 2     0.34139            2.49204  2015
# 2016 dataset:
# ...

# %%
# show the number of records and columns for each dataset
for i, df in enumerate(dfs):
    print (f'Size of 201{i+5} Report:', dfs[i].shape)
# Out:
# Size of 2015 Report: (158, 13)
# Size of 2016 Report: (157, 15)
# Size of 2017 Report: (155, 12)
# Size of 2018 Report: (146, 12)
# Size of 2019 Report: (146, 12)

# %% [markdown]
# #Because each row in these datasets represents a country, it is evident that the number of countries included in each report varies, implying that data from some countries is unavailable in some years!

# %%
# show column names for each dataset
for i, df in enumerate(dfs):
    print (f'Column names for 201{i+5} dataset:', dfs[i].columns, '\n')
# Out:
# Column names for 2015 dataset: Index(['Country', 'Region', 'Happiness_Rank', 'Happiness_Score',
#        'Standard_Error', 'Economy_(GDP_per_Capita)', 'Family',
#        'Health_(Life_Expectancy)', 'Freedom', 'Trust_(Government_Corruption)',
#        'Generosity', 'Dystopia_Residual', 'Year'],
#       dtype='object')
#
# Column names for 2016 dataset: Index(['Country', 'Region', 'Happiness_Rank', 'Happiness_Score',
#        'Lower_Confidence_Interval', 'Upper_Confidence_Interval',
#        'Economy_(GDP_per_Capita)', 'Family', 'Health_(Life_Expectancy)',
#        'Freedom', 'Trust_(Government_Corruption)', 'Generosity',
#        'Dystopia_Residual', 'Year', 'Standard Error'],
#       dtype='object')
#
# Column names for 2017 dataset: Index(['Country', 'Happiness Rank', 'Happiness Score', 'GDP', 'Family',
#        'Health', 'Freedom', 'Generosity', 'Trust', 'Region', 'Year',
#        'Standard Error'],
#       dtype='object')
#
# ...

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# #We need to abstract the datasets to a common name because they have slightly different naming conventions.

# %%
df_2015
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %%
df_2015.rename(columns = {'Economy (GDP per Capita)' : 'GDP',
                        'Health (Life Expectancy)' : 'Health',
                        'Trust (Government Corruption)' : 'Trust'}, inplace = True)

# %%
df_2015
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error      GDP   Family   Health  Freedom  \
# 0              7.587         0.03411  1.39651  1.34951  0.94143  0.66557
# ...

# %%
df_2016
# Out:
#          Country                           Region  Happiness Rank  \
# 0        Denmark                   Western Europe               1
# 1    Switzerland                   Western Europe               2
# 2        Iceland                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4        Finland                   Western Europe               5
# ..           ...                              ...             ...
# 152        Benin               Sub-Saharan Africa             153
# 153  Afghanistan                    Southern Asia             154
# 154         Togo               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
#
#      Happiness Score  Lower Confidence Interval  Upper Confidence Interval  \
# 0              7.526                      7.460                      7.592
# ...

# %%
df_2016.rename(columns = {'Economy (GDP per Capita)' : 'GDP',
                        'Health (Life Expectancy)' : 'Health',
                        'Trust (Government Corruption)' : 'Trust'}, inplace = True)

# %%
df_2016
# Out:
#          Country                           Region  Happiness Rank  \
# 0        Denmark                   Western Europe               1
# 1    Switzerland                   Western Europe               2
# 2        Iceland                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4        Finland                   Western Europe               5
# ..           ...                              ...             ...
# 152        Benin               Sub-Saharan Africa             153
# 153  Afghanistan                    Southern Asia             154
# 154         Togo               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
#
#      Happiness Score  Lower Confidence Interval  Upper Confidence Interval  \
# 0              7.526                      7.460                      7.592
# ...

# %%
df_2017
# Out:
#                       Country  Happiness.Rank  Happiness.Score  Whisker.high  \
# 0                      Norway               1            7.537      7.594445
# 1                     Denmark               2            7.522      7.581728
# 2                     Iceland               3            7.504      7.622030
# 3                 Switzerland               4            7.494      7.561772
# 4                     Finland               5            7.469      7.527542
# ..                        ...             ...              ...           ...
# 150                    Rwanda             151            3.471      3.543030
# 151                     Syria             152            3.462      3.663669
# 152                  Tanzania             153            3.349      3.461430
# 153                   Burundi             154            2.905      3.074690
# 154  Central African Republic             155            2.693      2.864884
#
# ...

# %%
df_2017.rename(columns = {'Happiness.Rank' : 'Happiness Rank',
                        'Happiness.Score' : 'Happiness Score',
                        'Economy..GDP.per.Capita.' : 'GDP',
                        'Health..Life.Expectancy.' : 'Health',
                        'Whisker.high' : 'Whisker high',
                          'Whisker.low' : 'Whisker low',
                        'Dystopia.Residual' : 'Dystopia Residual',
                        'Trust..Government.Corruption.' : 'Trust'}, inplace = True)

# %%
df_2017
# Out:
#                       Country  Happiness Rank  Happiness Score  Whisker high  \
# 0                      Norway               1            7.537      7.594445
# 1                     Denmark               2            7.522      7.581728
# 2                     Iceland               3            7.504      7.622030
# 3                 Switzerland               4            7.494      7.561772
# 4                     Finland               5            7.469      7.527542
# ..                        ...             ...              ...           ...
# 150                    Rwanda             151            3.471      3.543030
# 151                     Syria             152            3.462      3.663669
# 152                  Tanzania             153            3.349      3.461430
# 153                   Burundi             154            2.905      3.074690
# 154  Central African Republic             155            2.693      2.864884
#
# ...

# %%
df_2018
# Out:
#      Overall rank         Country or region  Score  GDP per capita  \
# 0               1                   Finland  7.632           1.305
# 1               2                    Norway  7.594           1.456
# 2               3                   Denmark  7.555           1.351
# 3               4                   Iceland  7.495           1.343
# 4               5               Switzerland  7.487           1.420
# ..            ...                       ...    ...             ...
# 151           152                     Yemen  3.355           0.442
# 152           153                  Tanzania  3.303           0.455
# 153           154               South Sudan  3.254           0.337
# 154           155  Central African Republic  3.083           0.024
# 155           156                   Burundi  2.905           0.091
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 0             1.592                    0.874                         0.681
# ...

# %%
df_2018.rename(columns = {'Overall rank' : 'Happiness Rank',
                        'Score' : 'Happiness Score',
                        'Country or region' : 'Country',
                        'Social support' : 'Family',
                        'Freedom to make life choices' : 'Freedom',
                        'GDP per capita' : 'GDP',
                        'Healthy life expectancy' : 'Health',
                        'Perceptions of corruption' : 'Trust'}, inplace = True)

# %%
df_2018
# Out:
#      Happiness Rank                   Country  Happiness Score    GDP  Family  \
# 0                 1                   Finland            7.632  1.305   1.592
# 1                 2                    Norway            7.594  1.456   1.582
# 2                 3                   Denmark            7.555  1.351   1.590
# 3                 4                   Iceland            7.495  1.343   1.644
# 4                 5               Switzerland            7.487  1.420   1.549
# ..              ...                       ...              ...    ...     ...
# 151             152                     Yemen            3.355  0.442   1.073
# 152             153                  Tanzania            3.303  0.455   0.991
# 153             154               South Sudan            3.254  0.337   0.608
# 154             155  Central African Republic            3.083  0.024   0.000
# 155             156                   Burundi            2.905  0.091   0.627
#
# ...

# %%
df_2019
# Out:
#      Overall rank         Country or region  Score  GDP per capita  \
# 0               1                   Finland  7.769           1.340
# 1               2                   Denmark  7.600           1.383
# 2               3                    Norway  7.554           1.488
# 3               4                   Iceland  7.494           1.380
# 4               5               Netherlands  7.488           1.396
# ..            ...                       ...    ...             ...
# 151           152                    Rwanda  3.334           0.359
# 152           153                  Tanzania  3.231           0.476
# 153           154               Afghanistan  3.203           0.350
# 154           155  Central African Republic  3.083           0.026
# 155           156               South Sudan  2.853           0.306
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 0             1.587                    0.986                         0.596
# ...

# %%
df_2019.rename(columns = {'Overall rank' : 'Happiness Rank',
                        'Score' : 'Happiness Score',
                        'Country or region' : 'Country',
                        'Social support' : 'Family',
                        'Freedom to make life choices' : 'Freedom',
                        'GDP per capita' : 'GDP',
                        'Healthy life expectancy' : 'Health',
                        'Perceptions of corruption' : 'Trust'}, inplace = True)

# %%
df_2019
# Out:
#      Happiness Rank                   Country  Happiness Score    GDP  Family  \
# 0                 1                   Finland            7.769  1.340   1.587
# 1                 2                   Denmark            7.600  1.383   1.573
# 2                 3                    Norway            7.554  1.488   1.582
# 3                 4                   Iceland            7.494  1.380   1.624
# 4                 5               Netherlands            7.488  1.396   1.522
# ..              ...                       ...              ...    ...     ...
# 151             152                    Rwanda            3.334  0.359   0.711
# 152             153                  Tanzania            3.231  0.476   0.885
# 153             154               Afghanistan            3.203  0.350   0.517
# 154             155  Central African Republic            3.083  0.026   0.000
# 155             156               South Sudan            2.853  0.306   0.575
#
# ...

# %%
#Creating "Year" column for each dataset.

# %%
# add year column for each dataset
for i, df in enumerate(dfs, 2015):
    df['Year'] = i

# %% [markdown]
# # we need to calculate "Standard Error" column for both 2016-2017 datasets based on Confidence Interval and Whisker values.

# %%
df_2016['Standard Error'] = round((df_2016['Upper Confidence Interval'] - df_2016['Lower Confidence Interval']) / 2, 3)

# %%
df_2017['Standard Error'] = round((df_2017['Whisker high'] - df_2017['Whisker low']) / 2, 3)

# %% [markdown]
# #Then, for both 2017-2019 datasets, add a "Standard Error" column by determining the average value of the prior years for each country. To accomplish this, we must first establish a temporary dataframe that combines the "Standard Error" columns from prior years in order to determine the "Standard Error" values for 2018-2019 datasets.

# %%
temp = pd.merge(df_2015[['Country', 'Standard Error']], df_2016[['Country', 'Standard Error']], on = 'Country')
temp.rename(columns = {'Standard Error_x' : 'Standard Error 2015',
                        'Standard Error_y' : 'Standard Error 2016'}, inplace = True)
standard_error_df = pd.merge(temp, df_2017[['Country', 'Standard Error']], on = 'Country')
standard_error_df.rename(columns = {'Standard Error' : 'Standard Error 2017'}, inplace = True)
standard_error_df.head(3)
# Out:
#        Country  Standard Error 2015  Standard Error 2016  Standard Error 2017
# 0  Switzerland              0.03411                0.081                0.068
# 1      Iceland              0.04884                0.168                0.118
# 2      Denmark              0.03328                0.066                0.060

# %%
# claculate Standard Error values for df2018
standard_error_df['Standard Error 2018'] = round(standard_error_df.mean(axis = 1), 4)
standard_error_df.head(3)
# Out:
# C:\Users\kanch\AppData\Local\Temp\ipykernel_25424\2625776619.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   standard_error_df['Standard Error 2018'] = round(standard_error_df.mean(axis = 1), 4)
#        Country  Standard Error 2015  Standard Error 2016  Standard Error 2017  \
# 0  Switzerland              0.03411                0.081                0.068
# 1      Iceland              0.04884                0.168                0.118
# 2      Denmark              0.03328                0.066                0.060
#
#    Standard Error 2018
# 0               0.0610
# 1               0.1116
# 2               0.0531

# %%
# claculate Standard Error values for 2019 dataset 
standard_error_df['Standard Error 2019'] = round(standard_error_df.mean(axis = 1), 3)
standard_error_df.head(3)
# Out:
# C:\Users\kanch\AppData\Local\Temp\ipykernel_25424\2171036725.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   standard_error_df['Standard Error 2019'] = round(standard_error_df.mean(axis = 1), 3)
#        Country  Standard Error 2015  Standard Error 2016  Standard Error 2017  \
# 0  Switzerland              0.03411                0.081                0.068
# 1      Iceland              0.04884                0.168                0.118
# 2      Denmark              0.03328                0.066                0.060
#
#    Standard Error 2018  Standard Error 2019
# 0               0.0610                0.061
# 1               0.1116                0.112
# 2               0.0531                0.053

# %%
dfs[3] = pd.merge(dfs[3], standard_error_df[['Standard Error 2018']], left_index=True, right_index=True)
dfs[3].rename(columns={'Standard Error 2018': 'Standard Error'}, inplace=True)

dfs[4] = pd.merge(dfs[4], standard_error_df[['Standard Error 2019']], left_index=True, right_index=True)
dfs[4].rename(columns={'Standard Error 2019': 'Standard Error'}, inplace=True)

# %%
#Columns that are not shared by all five reports are being removed.
for i, df in enumerate(dfs, 2015):
    # drop "Dystopia Residual" columns
    if 'Dystopia Residual' in df:
        df.drop(['Dystopia Residual'], inplace = True, axis = 1)
    # drop "Confidence Interval" columns
    if ('Lower Confidence Interval' and 'Upper Confidence Interval') in df:
        df.drop(['Lower Confidence Interval', 'Upper Confidence Interval'], inplace = True, axis = 1)
    # drop "Whisker" columns
    if ('Whisker.high' and 'Whisker.low') in df:
        df.drop(['Whisker.high', 'Whisker.low'], inplace = True, axis = 1)

# %%
# Assuming you have imported pandas as pd

# Check missing values for each dataset
for year, df in zip(range(2015, 2020), [df_2015, df_2016, df_2017, df_2018, df_2019]):
    print(f"Missing values in df_{year}:")
    print(df.isnull().sum())
    print("\n")
# Out:
# Missing values in df_2015:
# Country              0
# Region               0
# Happiness Rank       0
# Happiness Score      0
# Standard Error       0
# GDP                  0
# Family               0
# Health               0
# Freedom              0
# Trust                0
# Generosity           0
# Dystopia Residual    0
# dtype: int64
#
#
# Missing values in df_2016:
# Country                      0
# Region                       0
# Happiness Rank               0
# Happiness Score              0
# Lower Confidence Interval    0
# Upper Confidence Interval    0
# GDP                          0
# Family                       0
# Health                       0
# Freedom                      0
# Trust                        0
# Generosity                   0
# Dystopia Residual            0
# Standard Error               0
# dtype: int64
#
#
# Missing values in df_2017:
# Country              0
# Happiness Rank       0
# Happiness Score      0
# Whisker high         0
# ...

# %%
# This code will display rows with missing values in df_2018

missing_values_df_2018 = df_2018[df_2018.isnull().any(axis=1)]

# Print the DataFrame containing rows with missing values
print(missing_values_df_2018)
# Out:
#     Happiness Rank               Country  Happiness Score    GDP  Family  \
# 19              20  United Arab Emirates            6.774  2.096   0.776
#
#     Health  Freedom  Generosity  Trust
# 19    0.67    0.284       0.186    NaN

# %%
# Calculate the mean of the 'Trust' column from the previous years (df_2015, df_2016, df_2017)
previous_years = [df_2015, df_2016, df_2017]
mean_trust = sum([df['Trust'].mean() for df in previous_years]) / len(previous_years)

# Fill missing values in df_2018 with the calculated mean
df_2018['Trust'].fillna(mean_trust, inplace=True)

# %%
# show the number of records and columns for each dataset
for i, df in enumerate(dfs):
    print (f'Size of 201{i+5} Report:', dfs[i].shape)
# Out:
# Size of 2015 Report: (158, 13)
# Size of 2016 Report: (157, 15)
# Size of 2017 Report: (155, 12)
# Size of 2018 Report: (146, 13)
# Size of 2019 Report: (146, 13)

# %% [markdown]
# #Export checked data

# %%
#Export path
path = r'C:\Users\kanch\Documents\World Happiness Report\02 Data'

# %%
df_2015.to_csv(os.path.join(path, 'C:\\Users\\kanch\\Documents\\World Happiness Report\\02 Data', 'Cleaned Data', '2015.csv'))

# %%
df_2016.to_csv(os.path.join(path, 'C:\\Users\\kanch\\Documents\\World Happiness Report\\02 Data', 'Cleaned Data', '2016.csv'))

# %%
df_2017.to_csv(os.path.join(path, 'C:\\Users\\kanch\\Documents\\World Happiness Report\\02 Data', 'Cleaned Data', '2017.csv'))

# %%
df_2018.to_csv(os.path.join(path, 'C:\\Users\\kanch\\Documents\\World Happiness Report\\02 Data', 'Cleaned Data', '2018.csv'))

# %%
df_2019.to_csv(os.path.join(path, 'C:\\Users\\kanch\\Documents\\World Happiness Report\\02 Data', 'Cleaned Data', '2019.csv'))
